# %%
from openai import OpenAI
import os

client = OpenAI(
    base_url="http://127.0.0.1:8000/v1",
    # api_key='mt_live_w2p3ntk3spxfkai_oagvuevxpkxkp6ojnzrjysoxplbuvtew5t6cziq'
    api_key='mt_live_motm6dxokr4n7va_7al7qhqw7hlxmtyygmd2xhbus77nzyhhildioka'
    
)

response = client.chat.completions.create(
    model="small-llm",
    messages=[
        {"role": "system", "content": "You are a chatbot in a inference serving demo."},
        {"role": "user", "content": "Hello chatbot"},
        {
            "role": "assistant",
            "content": (
                "I am currently being watched by a demo."
            ),
        },
        {"role": "user", "content": "Say Hello to the people viewing this inference demo."},
    ],
    max_tokens=64,
    temperature=0.4,
)

print(response.choices[0].message.content)
# Out:
# Hello, I'm here to help you make sense of the world. I'm a chatbot designed to assist with inference tasks. I'm not a human, but I can provide assistance with various types of inference tasks, including:
#
# - **Inference**: Interpreting data, patterns, or relationships in information.
